# %%
# %pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from flask) (1.8.2)
# Requirement already satisfied: colorama in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from Jinja2>=3.1.2->flask) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thiru\anaconda3\envs\bland_ai\lib\site-packages (from requests) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests

import requests

url = "https://api.bland.ai/v1/calls"

payload = {
    "phone_number": "+19797393588",
    "task": "Remind the Customer about their appointment",
    "voice": "maya",
    "first_sentence": "Hello! This is a reminder about your appointment.",
    "wait_for_greeting": True,
    "block_interruptions": False,
    "interruption_threshold": 123,
    "model": "enhanced",
    "temperature": 0.7,
    "keywords": ["reminder", "appointment"],
    "pronunciation_guide": [{}],
    "transfer_phone_number": "+15512008317",
    "transfer_list": {"default": "+15512008317"},
    "language": "en-US",
    "calendly": {},
    "timezone": "America/New_York",
    "request_data": {},    
    "voicemail_message": "Hello, this ia a test message",
    "voicemail_action": "leave_message",
    "retry": {"wait": 10,
    "voicemail_action": "leave_message",
    "voicemail_message": "Hello, this is a test message."},
    "max_duration": 30,
    "record": True,
    "webhook":"https://b258-2601-8c-4e80-5b30-e4db-8948-7100-7183.ngrok-free.app/webhook",
    "metadata": {},
    "summary_prompt": "Summerize the call with See you Have a good one",
    "answered_by_enabled": True
}
headers = {
    "authorization": "sk-ydo9qfrlwapio8kyjsjjlpwosyzpf9xlgfeniwticjishj4a3m83yugap130j95169",
    "Content-Type": "application/json"
}

response = requests.post( url, json=payload, headers=headers)

print(response.text)
# Out:
# {"status":"success","message":"Call successfully queued.","call_id":"c1564d88-10e7-4edf-b953-5e18ed3e1147","batch_id":null}
